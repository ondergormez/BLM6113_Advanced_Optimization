# %% [markdown]
# # 1. Week - 23 February 2024 Friday

# %% [markdown]
# Ders notları [Google Classrom](https://classroom.google.com/u/0/c/NjY0NzE1ODgyMTk1) üzerinden paylaşılacaktır.
#
# # Ders İçeriği
# Vize
# Final
# Ödev (x3) %30
#
# Endüstri mühendisliğinde optimizasyon adı altında benzer bir ders var.
#
# Optimizasyon ismi çok genel bir isimdir. Bu nedenle kitap seçerken çok dikkat edilmelidir. İnceleyeceğimiz kitaplarda aşağıdaki konuları olanlar bizimle ilgilidir,
# * Convex optimization
# * Nonlinear optimization
# * Gradient Based Optimization
#
# # Line Search
# Alt search yöntemleri
# - Golden
# - Fibonacci
# - Povel
# - Bisection
#
# Sahibinden araba model yılı, ücreti
#
# x: model yılı
#
#
#
# y = mx + 10
#
# * aralık daraltarak m in değerini -10 dan başlatarak 10 a kadar götürerek hesap yapabiliriz
# * m[-10, 10]
#
# Renault Megan
#
# # Gradient Based
# Aşağıda alt yöntemler
# Gradient Descent
# Newton
# Modified Newton
# L M, C G
# Quassi Newton
# Stochastic Grad. Des
# Neistrov
# ve diğer yöntemler
#
#
# # Heuristic Methods
#
# Heuristic: Sezgisel
#
# Sezgisel olan yöntemler çok kolay öğrenilebilen metodlar
#
# - Arı kolonisi
# - Genetik algoritmalar
# - Parçacık/sürü optimizasyonu
# - Simulated Analoig
#
#
# # Convexity
# x^2 convex midir
# 2 kere türevini alıyoruz.
# birinci 2x
# ikinci türev 2
# 2. türevi 0 dan büyükse convex tir.
# bir grafikte 2 farklı nokta seçip birleştirdiğimde oluşan doğru eğrinin üzerindeyse convextir.
#
# # Optimizasyon Nedir?
#
# Bu ders özelinde aksi belirtilmedikçe vektörler sütun vektörü olur. Transpoz işareti de koyularak belirtilir.
#
# ## Diet Problem
# Find the "most economical" diet that satisfies the minimum nutrition requirements for good health.
# Amerikan ordusu kişi başı asker yemek ücretini 100$ olarak görünce.
# Bunun optimize etmeye çalışıyor. Fakat aşağıdakilerden feragat etmemeli
# * Öğün başına 3000 kalori
# * 70 gram protein
# * ...
#
# Gün sonunda 39$ lık bir maliyete kadar optimize edilebilmiş.
#
#
# # Closed Form vs Iterative Methods
# Closed form çözülmüş denklemleri  (örn: least square (LS) problem) iteratif bir şekilde çözmeye çalışma. Zaten gelinecek çözüm diğer kısımda elde edilene yakınsayacaktır.
#
#
# NOT: Ridge regression - Regularized LS araştırıp bakılabilir.
#
# SVM: Support Vector Machine
# * Amaç
#     * training datayı doğru classify etmek
#     * sınıflar arasındaki margini maksimize etmek
#
# * 2 farklı sınıf olduğunu biliyoruz ama bu sınıflar arasındaki ayrışma noktasını temsil eden bir doğru çizmemiz lazım
# * 2 boyutlu bir problemde svm bir doğru olur
# * 3 boyutlu bir problemde svm bir düzlem olur
# * 3 tan fazla da bir svm hyper plane olur.

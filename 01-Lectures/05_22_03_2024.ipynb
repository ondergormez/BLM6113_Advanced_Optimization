# %% [markdown]
# # 5. Week - 22 March 2024 Friday

# %% [markdown]
# Line Search Yöntemleri;
# * Bisection
# * Golden
#
# Gradient Based Optimization;
# * Newton - Raphson
#
# yöntemlerini işledik.

# %%
import numpy as np
from matplotlib import pyplot as plt

plt.rcParams["figure.figsize"] = [7.50, 3.50]
plt.rcParams["figure.autolayout"] = True


def f(x):
    return 3 * x * x * x
# return np.sin(x) + x + x * np.sin(x)


x = np.linspace(-100, 100, 100)

plt.plot(x, f(x), color='red')

plt.show()

# %%
import sympy as sp


def f(x):
    return x * x * x + 6 * x * x + 6
# return np.sin(x) + x + x * np.sin(x)


x = np.linspace(-100, 100, 100)

plt.plot(x, f(x), color='red')

plt.show()

# import library

# define symbolic variable
t = sp.symbols('t')

# define symbolic equation using with sp
eq = t ** 3 + 6 * t ** 2 + 6
# eq = sp. sp.exp(t / 2) * (sp.sin(t / 3) ** 2)

# find fourth order derivative
first_order_derivative = eq.diff(t, t)
first_order_derivative

# plt.plot(t, first_order_derivative, color='red')
# Out:
# 6*(t + 2)

# %% [markdown]
# # Bisection Method and Derivatives

# %%
def f_1(x):
    return 3 * x ** 4 + (x - 1) ** 2


x = np.linspace(-100, 100, 100)

plt.plot(x, f_1(x), color='red')

# %%
import numpy as np


def my_bisection(f, a, b, tol):
    # approximates a root, R, of f bounded
    # by a and b to within tolerance
    # | f(m) | < tol with m the midpoint
    # between a and b Recursive implementation

    # check if a and b bound a root
    if np.sign(f(a)) == np.sign(f(b)):
        raise Exception(
            "The scalars a and b do not bound a root")

    # get midpoint
    m = (a + b)/2

    if np.abs(f(m)) < tol:
        # stopping condition, report m as root
        return m
    elif np.sign(f(a)) == np.sign(f(m)):
        # case where m is an improvement on a.
        # Make recursive call with a = m
        return my_bisection(f, m, b, tol)
    elif np.sign(f(b)) == np.sign(f(m)):
        # case where m is an improvement on b.
        # Make recursive call with b = m
        return my_bisection(f, a, m, tol)

# %%
def f(x): return x**2 - 2


r1 = my_bisection(f, 0.0, 3, 0.0001)
print("r1 =", r1)
r01 = my_bisection(f, 0, 2, 0.01)
print("r01 =", r01)

print("f(r1) =", f(r1))
print("f(r01) =", f(r01))
# Out:
# r1 = 1.414215087890625
# r01 = 1.4140625
# f(r1) = 4.314817488193512e-06
# f(r01) = -0.00042724609375

# %%
def f(x): return 3 * x ** 4 + (x - 1) ** 2


r1 = my_bisection(f, 0, 20, 0.1)
print("r1 =", r1)
r01 = my_bisection(f, 0, 2, 0.01)
print("r01 =", r01)

print("f(r1) =", f(r1))
print("f(r01) =", f(r01))

r1 = my_bisection(f_1, 0, 2, 0.1)
print("r1 =", r1)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[6], line 4
#       1 def f(x): return 3 * x ** 4 + (x - 1) ** 2
# ----> 4 r1 = my_bisection(f, 0, 20, 0.1)
#       5 print("r1 =", r1)
#       6 r01 = my_bisection(f, 0, 2, 0.01)
#
# Cell In[4], line 12, in my_bisection(f, a, b, tol)
#       4 def my_bisection(f, a, b, tol):
#       5     # approximates a root, R, of f bounded
#       6     # by a and b to within tolerance
#    (...)
#       9
#      10     # check if a and b bound a root
#      11     if np.sign(f(a)) == np.sign(f(b)):
# ---> 12         raise Exception(
#      13             "The scalars a and b do not bound a root")
#      15     # get midpoint
#      16     m = (a + b)/2
#
# Exception: The scalars a and b do not bound a root
